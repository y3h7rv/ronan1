# %%
# import numpy as np
# from scipy.stats import ttest_ind
# import os
# from PIL import Image
# # 计算重建误差
# def calculate_reconstruction_error(image, reconstructed_image):
#     return np.mean((image - reconstructed_image) ** 2)
# images_group1 = os.listdir('C:\\Users\\abc\\original_photo')
# images_group2 = os.listdir('C:\\Users\\abc\\original_image_task2')
# reconstructed_images_group1 = os.listdir('C:\\Users\\abc\\reconstructed_photo')
# reconstructed_images_group2= os.listdir('C:\\Users\\abc\\reconstructed_image_task2')
# # 计算所有图像的重建误差
# # 计算所有图像的重建误差
# errors_group1 = [calculate_reconstruction_error(np.array(Image.open(os.path.join('C:\\Users\\abc\\original_photo', image))), np.array(Image.open(os.path.join('C:\\Users\\abc\\reconstructed_photo', reconstructed_image)))) for image, reconstructed_image in zip(images_group1, reconstructed_images_group1)]
# errors_group2 = [calculate_reconstruction_error(np.array(Image.open(os.path.join('C:\\Users\\abc\\original_image_task2', image))), np.array(Image.open(os.path.join('C:\\Users\\abc\\reconstructed_image_task2', reconstructed_image)))) for image, reconstructed_image in zip(images_group2, reconstructed_images_group2)]
# print(errors_group1)
# print(errors_group2)
# # 将重建误差归一化到0到1范围内
# errors_group1_normalized = (np.array(errors_group1) - np.min(errors_group1)) / (np.max(errors_group1) - np.min(errors_group1))
# errors_group2_normalized = (np.array(errors_group2) - np.min(errors_group2)) / (np.max(errors_group2) - np.min(errors_group2))
# print(errors_group1_normalized)
# print(errors_group2_normalized)
# # 使用Grubbs'假设检验
# t_stat, p_value = ttest_ind(errors_group1, errors_group2)

# # 如果p值小于0.05，我们拒绝零假设，即两组的重建误差显著不同
# if p_value < 0.05:
#     print("The reconstruction errors of the two groups are significantly different.")
# else:
#     print("The reconstruction errors of the two groups are not significantly different.")
import numpy as np
#from outliers import smirnov_grubbs as grubbs
import os
from PIL import Image
from skimage import io
#from skimage.measure import compare_mse
import cv2

#from skimage.measure import compare_ssim
from skimage.metrics import structural_similarity
list1=[]
list2=[]
# 计算重建误差
def calculate_reconstruction_error(image, reconstructed_image):
    return np.mean((image - reconstructed_image) ** 2)
# for _ in range(100):
#     image = io.imread('C:\\Users\\abc\\ronan_0202\\final_image_0202\\final_image_0202\\image0_final_'+str(_)+'.png')
#     reconstructed_image = io.imread('C:\\Users\\abc\\ronan_0202\\imgs_0202\\imgs_0202\\folder_'+str(_)+'.png')
        
#     # 打印图像的大小
#     #print(f'Size of original image: {image.shape}')
#     #print(f'Size of reconstructed image: {reconstructed_image.shape}')
#     #print(structural_similarity(image, reconstructed_image, multichannel=True))
#     list1.append(calculate_reconstruction_error(image, reconstructed_image))
#for _ in range(10):
   # image = io.imread('/root/ronan/final_image_0202_task2/image0_final_'+str(_)+'.png')
 #   reconstructed_image = io.imread('/root/ronan/imgs_0202_task2/image_cur__l2_0.01_bs1__'+str(_)+'.png')
image = io.imread('hy-tmp/ronan1/imgs_0204/image_cur_use_shiba_image0_l2_0.1_bs1__0_conss_5.png')
reconstructed_image = io.imread('hy-tmp/ronan1/imgs_0204/image_cur_use_shiba_image0_l2_0.1_bs1__0_conss_6.png')
  #  original_img=cv2.imread('C:\\Users\\abc\\test1\\final_image_0204\\image0_final_'+str(_)+'.png')
  #  final_img=cv2.imread('C:\\Users\\abc\\test1\\imgs_0204\\image_cur_use_generated_image0_l2_0.1_bs1__'+str(_)+'.png')
 #   original_img_array=np.array(original_img)
 #   final_img_array=np.array(final_img)
  #  mse=np.mean((original_img_array-final_img_array)**2)
    #print(mse)
print(calculate_reconstruction_error(image, reconstructed_image))
# images_group1 = os.listdir('C:\\Users\\abc\\original_image0_task1_0127\\original_image0')
# images_group2 = os.listdir('C:\\Users\\abc\\original_image0_task2_0127\\original_image0')
# reconstructed_images_group1 = os.listdir('C:\\Users\\abc\\imgs_task1_0127\\imgs\\images_to_test')
# reconstructed_images_group2= os.listdir('C:\\Users\\abc\\imgs_task2_0127\\imgs\\task2_img_for_test')
print(list1)
print(list2)
# 计算所有图像的重建误差
#errors_group1 = [calculate_reconstruction_error(np.array(Image.open(os.path.join('C:\\Users\\abc\\original_image0_task1_0127\\original_image0', image))), np.array(Image.open(os.path.join('C:\\Users\\abc\\imgs_task1_0127\\imgs\\images_to_test', reconstructed_image)))) for image, reconstructed_image in zip(images_group1, reconstructed_images_group1)]
#errors_group2 = [calculate_reconstruction_error(np.array(Image.open(os.path.join('C:\\Users\\abc\\original_image0_task2_0127\\original_image0', image))), np.array(Image.open(os.path.join('C:\\Users\\abc\\imgs_task2_0127\\imgs\\task2_img_for_test', reconstructed_image)))) for image, reconstructed_image in zip(images_group2, reconstructed_images_group2)]

# # 使用Grubbs'假设检验
# #for error in errors_group1:
#     #if np.any(grubbs.test(errors_group1, alpha=0.05)):
#     #    print("Found an outlier in group 1: ", error)
# print(grubbs.test(errors_group1, alpha=0.05))
# # for error in errors_group1:
#     #if np.any(grubbs.test(errors_group2, alpha=0.05)):
#         # print("Found an outlier in group 2: ", error)
# errors_group2.append(102.28580729)
# print(errors_group2)
# #errors_group2.append(102.28580729)
# print(grubbs.test(errors_group2, alpha=0.05))
# errors_group2.append(108.35286458)
# print(grubbs.test(errors_group2, alpha=0.05))
# print(errors_group1)
# print(errors_group2)
# i=0
# j=0
# for error in errors_group1:
#     errors_group2_with_error = errors_group2.copy()
#     errors_group2_with_error.append(error)
#     # if error in errors_group1:
#     #     print("The error belongs to errors_group2: ", error)
#     if (error not in (grubbs.test(errors_group2_with_error, alpha=0.05))):
#         print("The error does not belong to errors_group2: ", error)
#         i=i+1
#         result = grubbs.test(errors_group2_with_error, alpha=0.05)

#         for _ in errors_group2_with_error:
#             if(_ not in result):
#                 print("The error does not belong to errors_group2: ", _)
#     else:
#         print("The error belongs to errors_group2: ", error)
# print("-----------------------------------"+str(i))

# for error in errors_group2:
#     errors_group1_with_error = errors_group1.copy()
#     errors_group1_with_error.append(error)
#     result = grubbs.test(errors_group1_with_error, alpha=0.05)
#     if (error not in (result)):
#         print("The error does not belong to errors_group1: ", error) 
#         j=j+1
#         for _ in errors_group1_with_error:
#             if(_ not in result):
#                 print("The error does not belong to errors_group1: ", _)
#     else:
#         print("The error belongs to errors_group1: ", error)
    
# print("-----------------------------------"+str(j))
# import matplotlib.pyplot as plt
# from collections import Counter

# # 计算每个不同的重建误差在数据中的出现次数
# counter_group1 = Counter(errors_group1)
# counter_group2 = Counter(errors_group2)

# # 计算每个不同的重建误差对应的数据占比
# percentage_group1 = {error: count / len(errors_group1) for error, count in counter_group1.items()}
# percentage_group2 = {error: count / len(errors_group2) for error, count in counter_group2.items()}

# # 绘制图形
# plt.figure(figsize=(10, 6))
# plt.bar(list(percentage_group1.keys()), list(percentage_group1.values()), label='Group 1', alpha=0.5)
# plt.bar(list(percentage_group2.keys()), list(percentage_group2.values()), label='Group 2', alpha=0.5)
# plt.xlabel('Reconstruction Error')
# plt.ylabel('Data Percentage')
# plt.legend()
# plt.show()
# Out:
#   Input In [1]
#     print(calculate_reconstruction_error(image, reconstructed_image))
#     ^
# IndentationError: unexpected indent
